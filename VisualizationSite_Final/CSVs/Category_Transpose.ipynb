# %%
import pandas as pd

# %%
csv_file = "Analysis/CategoryCountsPerCountry.csv"
freq_df = pd.read_csv(csv_file, encoding="utf-8")
freq_df
# Out:
#     CategoryID  caCatCount  deCatCount  frCatCount  gbCatCount  inCatCount  \
# 0            1         288         329       331.0        97.0          83
# 1            2          55         156       155.0        13.0           6
# 2           10         659         659      1065.0       497.0         137
# 3           15          36          63        51.0        21.0           1
# 4           17         376         558       700.0        89.0          39
# 5           19          35          36        36.0         8.0           3
# 6           20         235         321       374.0       124.0           3
# 7           22         808        1193      1315.0       179.0         157
# 8           23         366         226       409.0        74.0          94
# 9           24        1254        1520      1111.0       322.0         572
# 10          25         531         527       563.0        58.0         214
# ...

# %%
freq_df.set_index('CategoryID', inplace=True)
freq_df
# Out:
#             caCatCount  deCatCount  frCatCount  gbCatCount  inCatCount  \
# CategoryID
# 1                  288         329       331.0        97.0          83
# 2                   55         156       155.0        13.0           6
# 10                 659         659      1065.0       497.0         137
# 15                  36          63        51.0        21.0           1
# 17                 376         558       700.0        89.0          39
# 19                  35          36        36.0         8.0           3
# 20                 235         321       374.0       124.0           3
# 22                 808        1193      1315.0       179.0         157
# 23                 366         226       409.0        74.0          94
# 24                1254        1520      1111.0       322.0         572
# 25                 531         527       563.0        58.0         214
# 26                 208         187       297.0        77.0          41
# ...

# %%
frequency_df = freq_df.transpose()
frequency_df
# Out:
# CategoryID     1      2       10     15     17    19     20      22     23  \
# caCatCount  288.0   55.0   659.0   36.0  376.0  35.0  235.0   808.0  366.0
# deCatCount  329.0  156.0   659.0   63.0  558.0  36.0  321.0  1193.0  226.0
# frCatCount  331.0  155.0  1065.0   51.0  700.0  36.0  374.0  1315.0  409.0
# gbCatCount   97.0   13.0   497.0   21.0   89.0   8.0  124.0   179.0   74.0
# inCatCount   83.0    6.0   137.0    1.0   39.0   3.0    3.0   157.0   94.0
# jpCatCount  346.0   93.0   377.0  110.0  442.0  25.0  285.0  1204.0  126.0
# krCatCount  260.0   27.0   340.0   47.0  160.0  26.0  206.0  1331.0  127.0
# mxCatCount  299.0   43.0   990.0   24.0  646.0  28.0  254.0  1893.0  233.0
# ruCatCount  466.0  200.0   609.0   66.0  432.0  72.0  349.0  2205.0  319.0
# usCatCount  127.0   56.0   433.0   48.0  122.0  29.0   59.0   234.0  142.0
#
# CategoryID      24     25     26     27     28     29   43
# caCatCount  1254.0  531.0  208.0  105.0   95.0   22.0  3.0
# ...

# %%
frequency_df.to_csv('Analysis/freq_transpose.csv')
