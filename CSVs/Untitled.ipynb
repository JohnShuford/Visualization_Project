# %%
import pandas as pd

# %%
csv_file = "Analysis/AllCountryDF.csv"
country_df = pd.read_csv(csv_file, encoding="utf-8")
country_df
# Out:
#        Unnamed: 0          channel_title  no_of_vids trending_date  \
# 0               0              SET India         192      17.14.11
# 1               1                  MSNBC         189      17.14.11
# 2               2                    FBE         188      17.14.11
# 3               3        The Young Turks         186      17.14.11
# 4               4                  REACT         183      17.14.11
# ...           ...                    ...         ...           ...
# 45694       45694    onsetfacilities.com           1      18.24.01
# 45695       45695         ladygagaarraza           1      17.20.11
# 45696       45696  So I Had This Idea...           1      18.14.02
# 45697       45697           Caters Clips           1      17.15.11
# 45698       45698              chris lee           1      17.23.11
#
#                                                    title  category_id  \
# 0      Crime Patrol Dial 100 - क्राइम पेट्रोल - Ep 65...           24
# ...
